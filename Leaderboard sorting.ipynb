# %%
import csv
from pymongo import MongoClient
import pandas as pd

# Your existing MongoDB Atlas and collection information
ATLAS_CONNECTION_STRING = "mongodb+srv://gaja:gaja123@cluster0.jdoybcv.mongodb.net/gameproject"
#ATLAS_CONNECTION_STRING = "YOUR_ATLAS_CONNECTION_STRING"
DB_NAME = "gameproject"
COLLECTION_NAME = "winnersdetails"

# Path to the CSV file
CSV_FILE_PATH = "exported_collection1.csv"

def get_winner_details():
    # Connect to MongoDB Atlas cluster
    client = MongoClient(ATLAS_CONNECTION_STRING)
    db = client[DB_NAME]
    collection2 = db[COLLECTION_NAME]

    # Perform MongoDB aggregation to get winners details
    pipeline = [
        {
            "$match": {"winner": True}
        },
        {
            "$group": {
                "_id": "$user_id",
                "winner_count": {"$sum": 1},
                "profileImage": {"$first": "$profileImage"},
                "email": {"$first": "$email"},
                "fname": {"$first": "$fname"},
                "mobile_number": {"$first": "$mobile_number"},
                "state": {"$first": "$state"},
                "address": {"$first": "$address"},
                "timestamp": {"$first": "$timestamp"}
            }
        },
        {
            "$sort": {
                "winner_count": -1,  # DESCENDING order for winner_count
                "timestamp": 1       # ASCENDING order for timestamp
            }
        }
    ]

    # Execute the aggregation pipeline
    result = collection2.aggregate(pipeline)

    # Convert the aggregation result to a list of dictionaries
    winners_list = list(result)

    # Create a DataFrame from the list of dictionaries
    df = pd.DataFrame(winners_list)

    # Sort the DataFrame by winner_count and timestamp
    df_sorted = df.sort_values(by=["winner_count", "timestamp"], ascending=[False, True])

    # Convert the DataFrame back to a list of dictionaries and return
    sorted_winners = df_sorted.to_dict(orient="records")

    # Save the sorted data to a new CSV file
    df_sorted.to_csv(CSV_FILE_PATH, index=False)

    return sorted_winners


# Call the function to get the sorted winners details and save to CSV
sorted_winners = get_winner_details()
print(sorted_winners)
# Out:
# [{'_id': '64bfb1f5e2f4422522371c3e', 'winner_count': 11, 'profileImage': ' ', 'email': 'vk921201@gmail.com', 'fname': None, 'mobile_number': '8881617809', 'state': None, 'address': None, 'timestamp': Timestamp('2023-07-25 17:01:51.478000')}, {'_id': '64bfafafe2f4422522371c34', 'winner_count': 6, 'profileImage': 'IMG_20190404_0012.jpg', 'email': 'harishbabu464@gmail.com', 'fname': 'Harish Babu', 'mobile_number': '7997080049', 'state': '', 'address': 'Fathenagar ', 'timestamp': Timestamp('2023-07-25 17:01:44.125000')}, {'_id': '64bf63118b4f53e06bf91021', 'winner_count': 5, 'profileImage': '', 'email': 'testing@gmail.com', 'fname': '', 'mobile_number': '9701655633', 'state': '', 'address': '', 'timestamp': Timestamp('2023-07-25 17:22:25.386000')}, {'_id': '64bfb1cce2f4422522371c3c', 'winner_count': 4, 'profileImage': '', 'email': 'hdhsuane363@gmail.com', 'fname': 'Anirudh', 'mobile_number': '6397587775', 'state': 'UT', 'address': 'Tilak Nagar, Lal Danth, Haldwani', 'timestamp': Timestamp('2023-07-25 17:04:48.251000')}, {'_id': '64bfb3660d2fd2f2bdb3695f', 'winner_count': 4, 'profileImage': ' ', 'email': 'zohraamtul2@gmail.com', 'fname': None, 'mobile_number': '8977447086', 'state': None, 'address': None, 'timestamp': Timestamp('2023-07-25 17:06:57.267000')}, {'_id': '64bfb0d0e2f4422522371c37', 'winner_count': 3, 'profileImage': '', 'email': 'tmohd1054@gmail.com', 'fname': 'MOHD ', 'mobile_number': '7838451955', 'state': 'UP', 'address': 'VILLAGE & POST SUITHA KALAN, DISTRICT JAUNPUR, UTTAR PRADESH', 'timestamp': Timestamp('2023-07-25 17:02:21.815000')}, {'_id': '64bfb3d40d2fd2f2bdb36969', 'winner_count': 3, 'profileImage': ' ', 'email': 'saroj789@gmail.com', 'fname': None, 'mobile_number': '8092929221', 'state': None, 'address': None, 'timestamp': Timestamp('2023-07-25 17:07:10.451000')}, {'_id': '64bfb4fb0d2fd2f2bdb3697f', 'winner_count': 3, 'profileImage': ' ', 'email': 'mallakusuma658@gmail.com', 'fname': None, 'mobile_number': '8143610720', 'state': None, 'address': None, 'timestamp': Timestamp('2023-07-25 17:22:57.892000')}, {'_id': '64bfb0dfe2f4422522371c38', 'winner_count': 2, 'profileImage': '', 'email': 'georgebenhur1@gmail.com', 'fname': 'George', 'mobile_number': '7702632077', 'state': 'TG', 'address': 'Hyderabad', 'timestamp': Timestamp('2023-07-25 17:00:25.320000')}, {'_id': '64bfb2ed0d2fd2f2bdb36937', 'winner_count': 2, 'profileImage': ' ', 'email': 'pandillapallipurnima10@gmail.com', 'fname': None, 'mobile_number': '6304153280', 'state': None, 'address': None, 'timestamp': Timestamp('2023-07-25 17:03:37.461000')}, {'_id': '64bf5ff38b4f53e06bf91012', 'winner_count': 2, 'profileImage': 'my pass photo.jpg', 'email': 'gajanan@gmail.com', 'fname': 'gajanan', 'mobile_number': '7387843993', 'state': 'TG', 'address': 'kphb colony', 'timestamp': Timestamp('2023-07-25 17:03:49.939000')}, {'_id': '64bf60208b4f53e06bf91013', 'winner_count': 2, 'profileImage': '', 'email': 'kinmart.app@gmail.com', 'fname': 'kumar', 'mobile_number': '9701655633', 'state': 'TG', 'address': 'moosapet', 'timestamp': Timestamp('2023-07-25 17:13:51.118000')}, {'_id': '64bfb23f0d2fd2f2bdb36911', 'winner_count': 1, 'profileImage': ' ', 'email': 'pandillapallipurnima@gmail.com', 'fname': None, 'mobile_number': '6304153280', 'state': None, 'address': None, 'timestamp': Timestamp('2023-07-25 17:00:59.261000')}, {'_id': '64bfae4ae2f4422522371c33', 'winner_count': 1, 'profileImage': ' ', 'email': 'dheeerajsinghdhooper@gmail.com', 'fname': None, 'mobile_number': '7985282516', 'state': None, 'address': None, 'timestamp': Timestamp('2023-07-25 17:02:28.994000')}, {'_id': '64bfb34d0d2fd2f2bdb36958', 'winner_count': 1, 'profileImage': ' ', 'email': 'www.samratsingh6441@gmail.com', 'fname': None, 'mobile_number': '8092929221', 'state': None, 'address': None, 'timestamp': Timestamp('2023-07-25 17:05:02.663000')}, {'_id': '64bfb4930d2fd2f2bdb3697b', 'winner_count': 1, 'profileImage': ' ', 'email': 'vangarisangeetha5@gmail.com', 'fname': None, 'mobile_number': '98852 ...

# %%
import csv
from pymongo import MongoClient
import pandas as pd

# Your existing MongoDB Atlas and collection information
# ATLAS_CONNECTION_STRING = "YOUR_ATLAS_CONNECTION_STRING"
ATLAS_CONNECTION_STRING = "mongodb+srv://gaja:gaja123@cluster0.jdoybcv.mongodb.net/gameproject"
DB_NAME = "gameproject"
COLLECTION_NAME = "winnersdetails"

# Path to the CSV file
CSV_FILE_PATH = "exported_collection2.csv"

def get_winner_details():
    # Connect to MongoDB Atlas cluster
    client = MongoClient(ATLAS_CONNECTION_STRING)
    db = client[DB_NAME]
    collection2 = db[COLLECTION_NAME]

    # Perform MongoDB aggregation to get winners details
    pipeline = [
        {
            "$match": {"winner": True}
        },
        {
            "$group": {
                "_id": "$user_id",
                "winner_count": {"$sum": 1},
                "profileImage": {"$first": "$profileImage"},
                "email": {"$first": "$email"},
                "fname": {"$first": "$fname"},
                "mobile_number": {"$first": "$mobile_number"},
                "state": {"$first": "$state"},
                "address": {"$first": "$address"},
                "timestamp": {"$first": "$timestamp"}
            }
        },
        {
            "$sort": {
                "winner_count": -1,  # DESCENDING order for winner_count
                "timestamp": 1       # ASCENDING order for timestamp
            }
        }
    ]

    # Execute the aggregation pipeline
    result = collection2.aggregate(pipeline)

    # Convert the aggregation result to a list of dictionaries
    winners_list = list(result)

    # Create a DataFrame from the list of dictionaries
    df = pd.DataFrame(winners_list)

    # Sort the DataFrame by winner_count and timestamp
    df_sorted = df.sort_values(by=["winner_count", "timestamp"], ascending=[False, True])

    # Print the DataFrame
    print(df_sorted)

    # Save the sorted data to a new CSV file
    df_sorted.to_csv(CSV_FILE_PATH, index=False)

    return df_sorted.to_dict(orient="records")


# Call the function to get the sorted winners details and print as DataFrame
sorted_winners = get_winner_details()
# Out:
#                          _id  winner_count           profileImage  \
# 0   64bfb1f5e2f4422522371c3e            11
# 1   64bfafafe2f4422522371c34             6  IMG_20190404_0012.jpg
# 2   64bf63118b4f53e06bf91021             5
# 3   64bfb1cce2f4422522371c3c             4
# 4   64bfb3660d2fd2f2bdb3695f             4
# 5   64bfb0d0e2f4422522371c37             3
# 6   64bfb3d40d2fd2f2bdb36969             3
# 7   64bfb4fb0d2fd2f2bdb3697f             3
# 8   64bfb0dfe2f4422522371c38             2
# 9   64bfb2ed0d2fd2f2bdb36937             2
# 10  64bf5ff38b4f53e06bf91012             2      my pass photo.jpg
# 11  64bf60208b4f53e06bf91013             2
# 12  64bfb23f0d2fd2f2bdb36911             1
# 13  64bfae4ae2f4422522371c33             1
# 14  64bfb34d0d2fd2f2bdb36958             1
# 15  64bfb4930d2fd2f2bdb3697b             1
# 16  64bfb5930d2fd2f2bdb36987             1
# 17  64bfb8b70d2fd2f2bdb369a7             1
#
#                                email        fname mobile_number state  \
# 0                 vk921201@gmail.com         None    8881617809  None
# 1            harishbabu464@gmail.com  Harish Babu    7997080049
# 2                  testing@gmail.com                 9701655633
# 3              hdhsuane363@gmail.com      Anirudh    6397587775    UT
# 4              zohraamtul2@gmail.com         None    8977447086  None
# 5                tmohd1054@gmail.com        MOHD     7838451955    UP
# 6                 saroj789@gmail.com         None    8092929221  None
# 7           mallakusuma658@gmail.com         None    8143610720  None
# 8            georgebenhur1@gmail.com       George    7702632077    TG
# 9   pandillapallipurnima10@gmail.com         None    6304153280  None
# 10                 gajanan@gmail.com      gajanan    7387843993    TG
# 11             kinmart.app@gmail.com        kumar    9701655633    TG
# 12    pandillapallipurnima@gmail.com         None    6304153280  None
# 13    dheeerajsinghdhooper@gmail.com         None    7985282516  None
# 14     www.samratsingh6441@gmail.com         None    8092929221  None
# 15       vangarisangeetha5@gmail.com         None    9885283202  None
# 16               kirangrgm@gmail.com         None    9980162343  None
# 17                nk461289@gmail.com         None    9392856983  None
#
#                                               address               timestamp
# 0                                                None 2023-07-25 17:01:51.478
# 1                                         Fathenagar  2023-07-25 17:01:44.125
# 2                                                     2023-07-25 17:22:25.386
# 3                    Tilak Nagar, Lal Danth, Haldwani 2023-07-25 17:04:48.251
# 4                                                None 2023-07-25 17:06:57.267
# 5   VILLAGE & POST SUITHA KALAN, DISTRICT JAUNPUR,... 2023-07-25 17:02:21.815
# 6                                                None 2023-07-25 17:07:10.451
# 7                                                None 2023-07-25 17:22:57.892
# 8                                           Hyderabad 2023-07-25 17:00:25.320
# 9                                                None 2023-07-25 17:03:37.461
# 10                                        kphb colony 2023-07-25 17:03:49.939
# 11                                           moosapet 2023-07-25 17:13:51.118
# 12                                               None 2023-07-25 17:00:59.261
# 13                                               None 2023-07-25 17:02:28.994
# 14                                               None 2023-07-25 17:05:02.663
# 15                                               None 2023-07-25 17:11:23.313
# 16                                               None 2023-07-25 17:18:35.295
# 17                                               None 2023-07-25 17:29:08.985

# %%
<!DOCTYPE html>
<html lang="en">
<head>
	<meta charset="UTF-8">
	<title>Leaderboard UI Design</title>
	<meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport">
	<link rel="stylesheet" type="text/css" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css">
	<link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css">
	<link rel="stylesheet" type="text/css" href="static/leader/css/style.css">
    <style>
        body {
            display: flex;
            justify-content: flex-start;
            align-items: center;
            height: 100vh;
            padding-top: 50px;
            padding-right: 200px; /* Add the desired padding value */
        }
    </style>
</head>
<body>

	<div class="container">
    <div class="row justify-content-center">
        <div class="col-lg-6">
            <h2> <a href="/">Winners List</a></h2>
            <table class="table">
                <thead>
                    <tr>
                        <th>Photo&Email</th>
                        <th>Name</th>
                        <th>Mobile</th>
                        <th>State</th>
                        <th>In Count</th>
                        <th>Date & Time</th>
                        <th>Wishes</th>
                    </tr>
                </thead>
                {% for winner in winners %}
                <tbody>
                    <tr>
                        <td>
                            <div class="d-flex align-items-center">
                                <img src="{{ url_for('static', filename='img/' + winner.profileImage) }}" class="circle-img circle-img--small mr-2" alt="User Img">
                                <div class="user-info__basic">
                                    <p class="text-muted mb-0">{{ winner.email[:4] }}.....{{ winner.email.split('@')[1] }}</p>
                                </div>
                            </div>
                        </td>
                        <td>
                            <div class="d-flex align-items-baseline">
                                <h4 class="mr-1"><h5 class="mb-0">{{ winner.fname }}</h5></h4>
                            </div>
                        </td>
                        <td>{{ winner.mobile_number[0:5] }}.....</td>
                        <td>{{ winner.state }}</td>
                        <td>{{ winner.winner_count  }}</td>
                        <td>{{ winner.timestamp }}</td>
                        <td>
                            <button class="btn btn-success btn-sm">Congratulate</button>
                        </td>
                    </tr>
                    {% endfor %}
                </tbody>
            </table>
        </div>
    </div>
</div>

<script src="https://code.jquery.com/jquery-3.2.1.slim.min.js"></script>
<script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"></script>
<script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"></script>

</body>
</html>
